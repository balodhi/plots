# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("D://finalCompilation.xlsx",sheetname='Accuracy')

# %%
origtrainloss = pd.read_csv("trainloss100-40c10.csv")

# %%
print(data.head())
# Out:
#   Comparison         C10   Unnamed: 2  Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0       Step  Depth40_12  Depth100_12  Depth40_24    Depth_3  Depth_3712
# 1          1    0.139223     0.366086    0.363782   0.317608    0.311498
# 2          2     0.53145     0.511619    0.633113    0.58143     0.54387
# 3          3    0.564303     0.460136    0.505709   0.639123    0.597857
# 4          4    0.497596     0.263321    0.578526   0.640024    0.597055
#
#    Unnamed: 6    Unnamed: 7  Unnamed: 8    Unnamed: 9  Unnamed: 10  \
# 0  Depth_3724  Depth_3_7_12  Depth_3_24  Depth_3_7_24  Depth_310_V
# 1    0.294471      0.368189    0.255108      0.296274     0.125401
# 2    0.452825      0.704527    0.498998      0.262921     0.418369
# 3    0.588842       0.65024    0.506911         0.375     0.734375
# 4    0.588441      0.624299    0.567809      0.682592     0.722556
#
#     Unnamed: 11   Unnamed: 12 Unnamed: 13
# 0  Depth_310_24  Depth_412_24  Depth_5624
# ...

# %%
print(data)
# Out:
#     Comparison         C10   Unnamed: 2  Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0         Step  Depth40_12  Depth100_12  Depth40_24    Depth_3  Depth_3712
# 1            1    0.139223     0.366086    0.363782   0.317608    0.311498
# 2            2     0.53145     0.511619    0.633113    0.58143     0.54387
# 3            3    0.564303     0.460136    0.505709   0.639123    0.597857
# 4            4    0.497596     0.263321    0.578526   0.640024    0.597055
# 5            5     0.61268     0.326823    0.523638   0.626803    0.575821
# 6            6    0.685998     0.441006    0.635617   0.435096    0.694912
# 7            7    0.748698     0.482372    0.624099   0.621494    0.725962
# 8            8    0.443109     0.524539     0.58764    0.69992    0.699419
# 9            9    0.669371     0.597556    0.643029   0.557191    0.599259
# 10          10    0.811498     0.549679    0.624199   0.696514    0.527244
# ...

# %%
orig4012 = data.iloc[:,1].values
orig4012 = orig4012[1:]
#print(orig4012)

# %%
orig10012 = data.iloc[:,2].values

orig10012 = orig10012[1:]
#print (orig10012)

# %%
my3724 = data.iloc[:,11].values
my3724 = my3724[1:]

# %%
my5624 = data.iloc[:,13]
my5624 = my5624[1:]

# %%
my562trainingloss = [1.483584404,
                    0.927458823,
0.72316128,
0.588894844,
0.504174471,
0.442567438,
0.39576,
0.359026849,
0.328090936,
0.302528143,
0.280228615,
0.262914181,
0.247426659,
0.238003626,
0.223567963,
0.218177184,
0.207817823,
0.201558307,
0.190068021,
0.183707774,
0.185104609,
0.179534331,
0.175029323,
0.172397703,
0.166862652,
0.16501832,
0.165949464,
0.161539212,
0.157554269,
0.157227591,
0.158628151,
0.152724206,
0.150269598,
0.155329376,
0.152929172,
0.151082158,
0.1438445,
0.145804465,
0.14530398,
0.136319816,
0.144423679,
0.141451895,
0.139432281,
0.146617234,
0.142071337,
0.136217609,
0.13531512,
0.135875449,
0.134239644,
0.137885138,
0.135627955,
0.136641368,
0.128606558,
0.134625241,
0.12824139,
0.132682204,
0.13388437,
0.128314748,
0.134967446,
0.130454868,
0.129844487,
0.130794883,
0.133358389,
0.128145874,
0.127318695,
0.125878394,
0.128709719,
0.126140326,
0.127607241,
0.121966116,
0.13100253,
0.126797929,
0.123994306,
0.127279148,
0.123480648,
0.130180404,
0.124941982,
0.124141864,
0.115391575,
ax.set_xticks(np.arange(0, 301, 50))
ax.set_xlim([0,300])
#ax.set_yticks(np.arange(0.8, 1., 0.005))
ax.set_ylim([0,1])

axloss = ax.twinx()

dnet1= ax.plot(1-orig10012,label = 'Validation error: DenseNet',color='r')
mynet1 = ax.plot(1-my5624, label = 'Validation error: Proposed', color='g')
trainloss = axloss.plot(origtrainloss['Value'], label = 'Training loss: DenseNet', color = 'r', linestyle = '--')
mynetloss = axloss.plot(my562trainingloss, label = 'Training loss:Proposed',linestyle='--', color = 'g')



ax.set_xlabel('Epochs')
ax.set_ylabel('Error (%)')
axloss.set_ylabel('Training loss')

axloss.set_yscale('log')
#axloss.semilogy(my562trainingloss,label='loss')
axloss.set_ylim(([1e-3, 1e0]))

lns = dnet1+trainloss+mynet1+mynetloss
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc='best')
#ax.legend(lns2, labs2,loc=9, bbox_to_anchor=(0.5, -0.13), ncol=2)
ax.grid(True)

plt.grid(linestyle='dotted')

#ax.legend(loc='best')
#axloss.legend(loc='best')

#axloss.set_yticks()
#axloss.set_yticklabels(y_labels)
plt.savefig('plot1.png', format='png', dpi=1000,bbox_inches='tight')
plt.show()

# %%
x = range(1,10)
fig2 = plt.figure()
ax2 = plt.gca()
ax2.set_xticks(np.arange(0, 301, 50))
ax2.set_xlim([0,300])
#ax.set_yticks(np.arange(0.8, 1., 0.005))
ax2.set_ylim([0,0.1])

axloss2 = ax2.twinx()

dnet2= ax2.plot(1-orig10012,label = 'Validation error: DenseNet',color='r')
mynet2 = ax2.plot(1-my5624, label = 'Validation error: Proposed', color='g')
trainloss2 = axloss2.plot(origtrainloss['Value'], label = 'Training loss: DenseNet', color = 'r', linestyle = '--')
mynetloss2 = axloss2.plot(my562trainingloss, label = 'Training loss: Proposed$',linestyle='--', color = 'g')



#mynetloss = axloss.plot(my562trainingloss, label = 'Traing loss (5,6)-24')

plt.grid(linestyle='dotted')

ax2.set_xlabel('Epochs')
ax2.set_ylabel('Error (%)')
axloss2.set_ylabel('Training Loss')

axloss2.set_yscale('log')
#axloss.semilogy(my562trainingloss,label='loss')
axloss2.set_ylim(([1e-3, 1e0]))

lns2 = dnet2+trainloss2+mynet2+mynetloss2
labs2 = [l.get_label() for l in lns2]
ax2.legend(lns, labs, loc='lower left')
#ax2.legend(lns2, labs2,loc=8, bbox_to_anchor=(-0.13, 1.2), ncol=1)
ax2.grid(True)


#ax.legend(loc='best')
#axloss.legend(loc='best')

#axloss.set_yticks()
#axloss.set_yticklabels(y_labels)
plt.savefig('plot2.png', format='png', dpi=1000,bbox_inches='tight')
plt.show()
plt.close()

# %%
fig, ax = plt.subplots() # create a new figure with a default 111 subplot
plt.plot(orig4012)
plt.show()
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
axins = zoomed_inset_axes(ax, 2.5, loc=2)

# %%
axins.plot(orig4012)

# %%
x1, x2, y1, y2 = 47, 60, 3.7, 4.6 # specify the limits
axins.set_xlim(x1, x2) # apply the x-limits
axins.set_ylim(y1, y2) # apply the y-limits
plt.yticks(visible=False)
plt.xticks(visible=False)
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="0.5")
# Out:
# (<mpl_toolkits.axes_grid1.inset_locator.BboxPatch at 0x139d7211160>,
# ...
#  <mpl_toolkits.axes_grid1.inset_locator.BboxConnector at 0x139d720a2e8>)

# %%
my3724[297:300]
# Out:
# array([0.943709909915924, 0.945813298225403, 0.944811701774597], dtype=object)
